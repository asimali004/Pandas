# %%
import pandas as pd

# %%
a=pd.read_excel("Car Wash Owners.xlsx")

# %%
a.columns
# Out:
# Index(['First name', 'Last name', 'Email', 'Email Status', 'Title', 'Location',
#        'Linkedin', 'Company', 'Company website', 'Company Industry',
#        'Company Founded', 'Company Size', 'Company Linkedin',
#        'Company Headquarters'],
#       dtype='object')

# %%
a.head()
# Out:
#   First name    Last name  Email  Email Status            Title  \
# 0        Jon        Kuhns    NaN           NaN            Owner
# 1        Tim        Smith    NaN           NaN            Owner
# 2       gary       weston    NaN           NaN            Owner
# 3       Mike        Adams    NaN           NaN            owner
# 4       Mike  Schlichtman    NaN           NaN  President-owner
#
#                                      Location  \
# 0      Allentown, Pennsylvania, United States
# 1            Palmetto, Florida, United States
# 2             Jupiter, Florida, United States
# 3              Tucson, Arizona, United States
# 4  Steamboat Springs, Colorado, United States
#
#                                             Linkedin  \
# 0  https://www.linkedin.com/sales/people/ACwAAAYZ...
# 1  https://www.linkedin.com/sales/people/ACwAAAME...
# 2  https://www.linkedin.com/sales/people/ACwAAAfx...
# 3  https://www.linkedin.com/sales/people/ACwAAAfF...
# ...

# %%
a.dropna(how="all",axis=1,inplace=True)

# %%
a
# Out:
#           First name             Last name                       Title  \
# 0                Jon                 Kuhns                       Owner
# 1                Tim                 Smith                       Owner
# 2               gary                weston                       Owner
# 3               Mike                 Adams                       owner
# 4               Mike           Schlichtman             President-owner
# 5               Mack                 Amick                       Owner
# 6            Richard                 Brown                       owner
# 7              Randy                 Ewing                       Owner
# 8               Matt              Squadere                       Owner
# 9              LARRY                 DAVIS              Business Owner
# 10           Lavenia                  Beck                       Owner
# 11              Kirk                Fisher                owner,Member
# ...

# %%
len(a)
# Out:
# 2490

# %%
a
# Out:
#           First name             Last name                       Title  \
# 0                Jon                 Kuhns                       Owner
# 1                Tim                 Smith                       Owner
# 2               gary                weston                       Owner
# 3               Mike                 Adams                       owner
# 4               Mike           Schlichtman             President-owner
# 5               Mack                 Amick                       Owner
# 6            Richard                 Brown                       owner
# 7              Randy                 Ewing                       Owner
# 8               Matt              Squadere                       Owner
# 9              LARRY                 DAVIS              Business Owner
# 10           Lavenia                  Beck                       Owner
# 11              Kirk                Fisher                owner,Member
# ...

# %%
print(a["Company website"].value_counts().cumsum())
print(a["Company Industry"].value_counts().cumsum())
print(a["Company Founded"].value_counts().cumsum())
print(a["Company Size"].value_counts().cumsum())
print(a["Company Linkedin"].value_counts().cumsum())
print(a["Company Headquarters"].value_counts().cumsum())
# Out:
# busybeecarwash.cc                     2
# washmasters.net                       4
# circlemarinacarwash.com               6
# williamscleaning.com                  8
# ekgametime.com                       10
# futurewash.com                       12
# parksbestcarwash.com                 14
# thatcarwash.com                      16
# landersmclartydcjal.com              18
# truebluecw.com                       20
# flcarwash.com                        22
# samscarwash.com                      24
# cleanmachinetouchlesscarwash.com     26
# taggngo.com                          28
# californiahandwash.com               30
# twinscarwash.com                     32
# wordpress.com                        34
# aquacville.com                       36
# jetzusa.com                          38
# kobraenterprises.com                 40
# myfavcarwash.com                     42
# silverstarcarwashes.com              44
# mintecocarwash.com                   46
# ...
