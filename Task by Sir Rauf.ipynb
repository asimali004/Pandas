# %%
import pandas as pd

# %%
df=pd.read_csv("performance.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
# Province            180 non-null object
# City                180 non-null object
# Area                180 non-null object
# Company             180 non-null object
# Status              180 non-null object
# Delivery Time       180 non-null object
# Delivery Charges    180 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 9.9+ KB

# %%
df.head()
# Out:
#   Province        City    Area Company     Status Delivery Time  \
# 0    Sindh  Hyderababd    Main   BLUEX  Delivered       13 Days
# 1   Punjab      Jampur    Main   BLUEX  Delivered       10 Days
# 2    Sindh     KARACHI    Main   BLUEX  Delivered        6 Days
# 3   Punjab   Wah Cantt  Tehsil   BLUEX  Delivered        9 Days
# 4    Sindh     Karachi    Main   BLUEX  Delivered        6 Days
#
#    Delivery Charges
# 0               150
# 1               150
# 2               150
# 3               150
# 4               150

# %%
import re
Delivery_time= df['Delivery Time']
li= list()
for i in range(Delivery_time.size):
    res= re.search(r'\d*', Delivery_time[i])
    li.append(int(res.group()))
df['Delivery Time']= li

# %%
df.head()
# Out:
#   Province        City    Area Company     Status  Delivery Time  \
# 0    Sindh  Hyderababd    Main   BLUEX  Delivered             13
# 1   Punjab      Jampur    Main   BLUEX  Delivered             10
# 2    Sindh     KARACHI    Main   BLUEX  Delivered              6
# 3   Punjab   Wah Cantt  Tehsil   BLUEX  Delivered              9
# 4    Sindh     Karachi    Main   BLUEX  Delivered              6
#
#    Delivery Charges
# 0               150
# 1               150
# 2               150
# 3               150
# 4               150

# %%
df["Company"].value_counts()
# Out:
# BLUEX    91
# TRAX     89
# Name: Company, dtype: int64

# %%
df1=df[df["Company"]=="TRAX"]

# %%
df2=df[df["Company"]=="BLUEX"]

# %%
df1.head()
# Out:
#    Province            City    Area Company     Status  Delivery Time  \
# 65  Capital       Islamabad    Main    TRAX  Delivered              5
# 66   Punjab        Arifwala  Tehsil    TRAX  Delivered              7
# 67  Capital       Islamabad    Main    TRAX  Delivered              3
# 68   Punjab  Ahmed Pur East    Main    TRAX  Delivered              5
# 69    Sindh         Karachi    Main    TRAX  Delivered              2
#
#     Delivery Charges
# 65               150
# 66               150
# 67               150
# 68               150
# 69               150

# %%
df2.tail()
# Out:
#     Province              City    Area Company             Status  \
# 161   Punjab        Shahdadpur  Tehsil   BLUEX  Returned Recieved
# 162   Punjab            Lahore    Main   BLUEX  Returned Recieved
# 163    Sindh  Hyderabad, Sindh    Main   BLUEX  Returned Recieved
# 164   Punjab             Gojra    Main   BLUEX  Returned Recieved
# 165    Sindh        Sadiq Abad    Main   BLUEX  Returned Recieved
#
#      Delivery Time  Delivery Charges
# 161             11               180
# 162              9               180
# 163              6               180
# 164              9               180
# 165              7               180

# %%
df1["Status"].value_counts()
# Out:
# Delivered            75
# Returned Recieved    14
# Name: Status, dtype: int64

# %%
df2["Status"].value_counts()
# Out:
# Delivered            65
# Returned Recieved    26
# Name: Status, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df2=df1.iloc[:,5:7].mean()

# %%
df2.plot(kind="bar")

# %%
df1
# Out:
#         Province                City     Area Company             Status  \
# 65       Capital           Islamabad     Main    TRAX          Delivered
# 66        Punjab            Arifwala   Tehsil    TRAX          Delivered
# 67       Capital           Islamabad     Main    TRAX          Delivered
# 68        Punjab      Ahmed Pur East     Main    TRAX          Delivered
# 69         Sindh             Karachi     Main    TRAX          Delivered
# 70        Punjab           Bhalwal .     Main    TRAX          Delivered
# 71        Punjab            Samundri     Main    TRAX          Delivered
# 72        Punjab     Tobah Tek Singh     Main    TRAX          Delivered
# 73        Punjab                Dina     Main    TRAX          Delivered
# 74         Sindh             Karachi     Main    TRAX          Delivered
# 75        Punjab           Fasalabad     Main    TRAX          Delivered
# 76           KPK            Peshawar     Main    TRAX          Delivered
# ...

# %%
df1.columns.names=["Company"]

# %%
df
# Out:
# Company     Province              City     Area Company             Status  \
# 0              Sindh        Hyderababd     Main   BLUEX          Delivered
# 1             Punjab            Jampur     Main   BLUEX          Delivered
# 2              Sindh           KARACHI     Main   BLUEX          Delivered
# 3             Punjab         Wah Cantt   Tehsil   BLUEX          Delivered
# 4              Sindh           Karachi     Main   BLUEX          Delivered
# 5             Punjab          Hasilpur     Main   BLUEX          Delivered
# 6             Punjab            Multan     Main   BLUEX          Delivered
# 7             Punjab        Gujranwala     Main   BLUEX          Delivered
# 8             Punjab        Rawalpindi     Main   BLUEX          Delivered
# 9              Sindh           Karachi     Main   BLUEX          Delivered
# 10            Punjab           Sahiwal     Main   BLUEX          Delivered
# ...

# %%
df9=df.groupby("Company")

# %%
df9=df9.mean()

# %%
df9.plot(kind="bar")

# %%
df10=df.groupby("Area")

# %%
df10=df10.mean()
df10.plot(kind="bar")

# %%
df.groupby("Company")["Status"].value_counts().plot(kind="bar")

# %%
df.groupby("Province").mean().plot(kind="bar")

# %%
df.groupby(["Company","Province"]).mean().plot(kind="bar")
